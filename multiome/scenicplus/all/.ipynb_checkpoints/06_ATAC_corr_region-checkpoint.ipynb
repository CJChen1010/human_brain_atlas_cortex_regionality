# %% [markdown]
# # Correlation of all ATAC across regions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
import scanpy as sc
import decoupler as dc
import os
from pathlib import Path
import numpy as np
from scipy.stats import pearsonr
rcParams["font.family"] = "Ubuntu Mono"

# %%
os.chdir("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/")
os.chdir("other_celltypes")
figure_dir = "/tscc/projects/ps-epigen/users/biy022/biccn/analysis/final_figures/ATAC_corr/"
file_dir = "/tscc/projects/ps-epigen/users/biy022/biccn/analysis/final_files/ATAC_corr_tables/"

# %%
region_align = ["A24", "A9", "FI", "M1C", "S1C", "MTG", "A1C", "AnG", "V1C"]
def generate_corr_matrix(cell_type_name):
    atac_object = sc.read_h5ad(f"{cell_type_name}_atac_matrix.h5ad")
    atac_counts = atac_object
    if atac_object.raw != None:
        atac_counts = atac_object.raw.to_adata()
    atac_region_counts = dc.get_pseudobulk(
        adata=atac_counts,
        sample_col="Region",
        groups_col=None,
        min_cells=0,
        min_counts=0,
        min_prop=0.0,
        min_smpls=0,
        remove_empty=True,
        mode="sum"
    )
    sc.pp.normalize_total(atac_region_counts, target_sum=1e6)
    sc.pp.log1p(atac_region_counts, base=2)

    result_matrix = np.zeros((len(region_align), len(region_align)))
    result_df = pd.DataFrame(result_matrix, index=region_align, columns=region_align)

    for i in range(0, len(region_align)):
        for j in range(i, len(region_align)):
            region_x = region_align[i]
            region_y = region_align[j]
            atac_x = atac_region_counts[region_x, :].X[0]
            atac_y = atac_region_counts[region_y, :].X[0]
            result_df.loc[region_x, region_y] = pearsonr(atac_x, atac_y)[0]
            result_df.loc[region_y, region_x] = pearsonr(atac_x, atac_y)[0]

    sns.heatmap(result_df, vmin=0.5, vmax=1.0)
    plt.savefig(Path(figure_dir) / f"{cell_type_name}-ATAC_corr.pdf", dpi=250)
    result_df.to_csv(Path(file_dir) / f"{cell_type_name}-ATAC_corr.tsv", sep="\t", header=True, index=True)

# %%
generate_corr_matrix("L4_IT")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("L2_3_IT")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("L5_IT")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("L6_IT")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("Oligo")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("Astro")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
generate_corr_matrix("PVALB")
# Out:
# /tscc/nfs/home/biy022/miniconda3/envs/scenicplus/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
