# %% [markdown]
# # Use clusterProfiler GO term analysis

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/L4_IT/")

# %%
background.file <- "rostral_caudal_spearman/full_gene_list.tsv"
background.table <- read.table(background.file, header = FALSE, sep = "\t")
background.list <- background.table$V1

# %%
### Positive correlated genes

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/positive_genes_bh_7e-1_5e-2_donor_replicate.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/positive_genes_bh_7e-1_5e-2_donor_replicate.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/negative_genes_bh_7e-1_5e-2_donor_replicate.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/negative_genes_bh_7e-1_5e-2_donor_replicate.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %% [markdown]
# ## Plot the result

# %%
result_table <- read.table(
    "rostral_caudal_spearman/positive_genes_bh_7e-1_5e-2_donor_replicate.gsea.tsv",
    header = TRUE, sep = "\t", row.names = 1
)

# %%
plot_dir <- "../../../../analysis/scenicplus/L4_IT/figures/"

# %%
options(repr.plot.width = 16, repr.plot.height = 12)
result_table$nlogpvalue <- -log10(result_table$pvalue)
result_table$ID <- factor(result_table$ID, levels = rev(result_table$ID))
plot <- ggplot(result_table, aes(x=ID, y=nlogpvalue)) +
    geom_bar(stat = "identity", fill = "skyblue", colour = "black", linewidth = 1) +
    geom_text(aes(label = Description), hjust = 1.05, size=5) +
    coord_flip() +
    theme_classic() +
    theme(
        axis.title.x = element_text(size = 20),
        axis.title.y = element_text(size = 20),
        axis.text.x = element_text(size=17.5),
        axis.text.y = element_blank()
    )
ggsave(
    plot = plot,
    filename = "L4_IT_corr_donor_replicate_positive_RNA_GSEA.png",
    path = plot_dir,
    width = 16,
    height = 12,
    dpi = 300,
    device = "png"
)
plot
# Out:
# plot without title

# %% [markdown]
# ## Without cutoff on corr scores

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/L4_IT/")

# %%
background.file <- "rostral_caudal_spearman/full_gene_list.tsv"
background.table <- read.table(background.file, header = FALSE, sep = "\t")
background.list <- background.table$V1

# %%
### Positive correlated genes

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/positive_genes_bh_1e-2_donor_replicate.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/positive_genes_bh_1e-2_donor_replicate.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/negative_genes_bh_1e-2_donor_replicate.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/negative_genes_bh_1e-2_donor_replicate.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %% [markdown]
# ## Plot the result

# %%
result_table <- read.table(
    "rostral_caudal_spearman/positive_genes_bh_1e-2_donor_replicate.gsea.tsv",
    header = TRUE, sep = "\t", row.names = 1
)

# %%
plot_dir <- "../../../../analysis/scenicplus/L4_IT/figures/"

# %%
options(repr.plot.width = 16, repr.plot.height = 6)
result_table$nlogpvalue <- -log10(result_table$pvalue)
result_table$ID <- factor(result_table$ID, levels = rev(result_table$ID))
plot <- ggplot(result_table, aes(x=ID, y=nlogpvalue)) +
    geom_bar(stat = "identity", fill = "skyblue", colour = "black", linewidth = 1) +
    geom_text(aes(label = Description), hjust = 1.05, size=5) +
    coord_flip() +
    theme_classic() +
    theme(
        axis.title.x = element_text(size = 20),
        axis.title.y = element_text(size = 20),
        axis.text.x = element_text(size=17.5),
        axis.text.y = element_blank()
    )
# ggsave(
#     plot = plot,
#     filename = "L4_IT_corr_donor_replicate_positive_RNA_GSEA_1e-2.png",
#     path = plot_dir,
#     width = 16,
#     height = 12,
#     dpi = 300,
#     device = "png"
# )
plot
# Out:
# plot without title

# %% [markdown]
# ## For all other celltypes

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd(
    "/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/other_celltypes/corr_genes/"
)

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_positive.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_positive.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_positive_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# --> No gene can be mapped....
#
# --> Expected input gene ID: PSME4,CDY2B,CBL,PTGDR2,MNS1,SCGB1A1
#
# --> return NULL...
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_negative.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_negative.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_negative_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %% [markdown]
# ## Jorstad 2023 Science filters

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/L4_IT/")

# %%
background.file <- "rostral_caudal_spearman/full_gene_list.tsv"
background.table <- read.table(background.file, header = FALSE, sep = "\t")
background.list <- background.table$V1

# %%
### Positive correlated genes

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/positive_genes_all_7e-1_mid7_5e-1.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/positive_genes_all_7e-1_mid7_5e-1.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %%
curr.table <- read.table(
    "rostral_caudal_spearman/negative_genes_all_7e-1_mid7_5e-1.tsv",
    header = FALSE, sep = "\t")
curr.list <- curr.table$V1

curr.result <- enrichGO(
    gene = curr.list,
    universe = background.list,
    keyType = "SYMBOL",
    OrgDb = org.Hs.eg.db,
    ont = "BP",
    pvalueCutoff = 0.1,
    readable = TRUE,
)
curr.result.simplified <- clusterProfiler::simplify(curr.result)
output.file <- "rostral_caudal_spearman/negative_genes_all_7e-1_mid7_5e-1.gsea.tsv"
write.table(
    curr.result.simplified@result,
    output.file,
    quote = FALSE,
    col.names = TRUE,
    row.names = TRUE,
    sep = "\t"
)

# %% [markdown]
# ## Plot the result

# %%
result_table <- read.table(
    "rostral_caudal_spearman/positive_genes_all_7e-1_mid7_5e-1.gsea.tsv",
    header = TRUE, sep = "\t", row.names = 1
)

# %%
plot_dir <- "../../../../analysis/scenicplus/L4_IT/figures/"

# %%
options(repr.plot.width = 16, repr.plot.height = 6)
result_table$nlogpvalue <- -log10(result_table$pvalue)
result_table$ID <- factor(result_table$ID, levels = rev(result_table$ID))
plot <- ggplot(result_table, aes(x=ID, y=nlogpvalue)) +
    geom_bar(stat = "identity", fill = "skyblue", colour = "black", linewidth = 1) +
    geom_text(aes(label = Description), hjust = 1.05, size=5) +
    coord_flip() +
    theme_classic() +
    theme(
        axis.title.x = element_text(size = 20),
        axis.title.y = element_text(size = 20),
        axis.text.x = element_text(size=17.5),
        axis.text.y = element_blank()
    )
# ggsave(
#     plot = plot,
#     filename = "L4_IT_corr_donor_replicate_positive_RNA_GSEA_1e-2.png",
#     path = plot_dir,
#     width = 16,
#     height = 12,
#     dpi = 300,
#     device = "png"
# )
plot
# Out:
# plot without title

# %% [markdown]
# ## Jorstad all cell types

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd(
    "/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/scenicplus/other_celltypes/corr_genes_jorstad/"
)

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_positive.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_positive.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_positive_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# --> No gene can be mapped....
#
# --> Expected input gene ID: TEKT2,TGFB1,HSD17B4,CALR3,SPATA31D1,RSPH6A
#
# --> return NULL...
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_negative.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_negative.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_negative_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"
# --> No gene can be mapped....
#
# --> Expected input gene ID: ID4,IFTAP,DPY19L2P2,ZRANB3,NKX2-1,CATSPER1
#
# --> return NULL...

# %% [markdown]
# # GSEA all celltypes (padjusted < 0.05, |corr| > 0.7)

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/")
setwd("scenicplus/other_celltypes/corr_genes_7e-1_5e-2//")

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_positive.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_positive.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_positive_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# --> No gene can be mapped....
#
# --> Expected input gene ID: SPP1,GDF7,WFDC2,CADM1,PAFAH1B1,TIMP1
#
# --> return NULL...
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_negative.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_negative.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_negative_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %% [markdown]
# # New perspective: Sensorimotor Transmodal axis

# %%
suppressPackageStartupMessages({
    library(clusterProfiler)
    library(ggplot2)
    library(fs)
    library(tidyverse)
    library(org.Hs.eg.db)
})

# %%
setwd("/tscc/projects/ps-epigen/users/biy022/biccn/data/SNAREdata/")
setwd("scenicplus/other_celltypes/corr_genes_ST_7e-1_5e-2/")

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_positive.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_positive.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_positive_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"

# %%
for (file in dir_ls("./", glob = "*full*")) {
    celltype <- str_split_1(file, "_full_list.tsv")[1]
    print(celltype)
    flush.console()
    
    background_file <- file
    background_table <- read.table(background_file, header = FALSE, sep = "\t")
    background_list <- background_table$V1
    
    if (file_size(sprintf("%s_negative.tsv", celltype)) <= 0) {
        next
    }
    curr_table <- read.table(sprintf("%s_negative.tsv", celltype), header = FALSE, sep = "\t")
    curr_list <- curr_table$V1

    curr_result <- enrichGO(
        gene = curr_list,
        universe = background_list,
        keyType = "SYMBOL",
        OrgDb = org.Hs.eg.db,
        ont = "BP",
        pvalueCutoff = 0.1,
        readable = TRUE,
    )
    if (is.null(curr_result)) {
        next
    }
    
    curr_result_simplified <- clusterProfiler::simplify(curr_result)
    output_file <- sprintf("%s_negative_gsea.tsv", celltype)
    write.table(
        curr_result_simplified@result,
        output_file,
        quote = FALSE,
        col.names = TRUE,
        row.names = TRUE,
        sep = "\t"
    )
}
# Out:
# [1] "Astro"
# [1] "Chandelier"
# [1] "Endo"
# [1] "L2_3_IT"
# [1] "L4_IT"
# [1] "L5_6_NP"
# [1] "L5_ET"
# [1] "L5_IT"
# [1] "L6B"
# [1] "L6_CT"
# [1] "L6_IT_Car3"
# [1] "L6_IT"
# [1] "LAMP5_LHX6"
# [1] "LAMP5"
# [1] "Micro"
# [1] "OPC"
# [1] "Oligo"
# [1] "PAX6"
# [1] "PVALB"
# [1] "SNCG"
# [1] "SST_CHODL"
# [1] "SST"
# [1] "VIP"
# [1] "VLMC"
